# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
df1 = pd.read_csv('Resources/athletic_sales_2020.csv')
df2 = pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
df1 = pd.read_csv('Resources/athletic_sales_2020.csv')
df1.head(-5)
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1287    West Gear      1128299     12/29/20       West    California
# 1288       Kohl's      1189833     12/29/20    Midwest     Minnesota
# 1289    West Gear      1128299     12/29/20       West    California
# 1290       Kohl's      1189833     12/29/20    Midwest     Minnesota
# 1291    West Gear      1128299     12/29/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
df2 = pd.read_csv('Resources/athletic_sales_2021.csv')
df2.head(-5)
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8336  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 8337  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 8338       Amazon      1185732     12/30/21  Northeast         Maine
# 8339       Amazon      1185732     12/30/21  Northeast         Maine
# 8340  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
#
#                city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
# Check the 2021 sales data types.
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
df1_df2 = pd.concat([df1, df2], axis="rows", join="inner").reset_index(drop=True)
df1_df2
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640       Amazon      1185732     12/31/21  Northeast         Maine
# 9641       Amazon      1185732     12/31/21  Northeast         Maine
# 9642  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
df1_df2.isnull().any()
# Out:
# retailer            False
# retailer_id         False
# invoice_date        False
# region              False
# state               False
# city                False
# product             False
# price_per_unit      False
# units_sold          False
# total_sales         False
# operating_profit    False
# sales_method        False
# dtype: bool

# %%
# Check the data type of each column
df1_df2.dtypes
# Out:
# index                   int64
# retailer_x             object
# retailer_id             int64
# invoice_date_x         object
# region_x               object
# state_x                object
# city_x                 object
# product                object
# price_per_unit          int64
# units_sold              int64
# total_sales             int64
# operating_profit_x    float64
# sales_method_x         object
# retailer_y             object
# invoice_date_y         object
# region_y               object
# state_y                object
# city_y                 object
# operating_profit_y    float64
# sales_method_y         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
df1_df2['invoice_date'] = pd.to_datetime(df1_df2['invoice_date'], errors = "coerce")
df1_df2.head()
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732   2020-01-01  Northeast      New York
# 1  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3  Foot Locker      1185732   2020-01-01  Northeast      New York
# 4  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    total_sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# ...

# %%
# Confirm that the "invoice_date" data type has been changed.
df1_df2['invoice_date']
# Out:
# 0      2020-01-01
# 1      2020-01-01
# 2      2020-01-01
# 3      2020-01-01
# 4      2020-01-01
#           ...
# 9638   2021-12-31
# 9639   2021-12-31
# 9640   2021-12-31
# 9641   2021-12-31
# 9642   2021-12-31
# Name: invoice_date, Length: 9643, dtype: datetime64[ns]

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".

grouped_data = df1_df2.groupby(["region", "state", "city"])['units_sold'].agg(Total_Products_Sold=("sum"))




# Show the top 5 results.
grouped_data.sort_values(by=(['Total_Products_Sold']), ascending = False).head(5)
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %%
#grouped_data
# Out:
#                                          grouped_data
# region    state          city
# Midwest   Illinois       Chicago                25407
#           Indiana        Indianapolis           26332
#           Iowa           Des Moines             23446
#           Kansas         Wichita                29463
#           Michigan       Detroit                50095
#           Minnesota      Minneapolis            20415
#           Missouri       St. Louis              36404
#           Montana        Billings               42713
#           Nebraska       Omaha                  19154
#           North Dakota   Fargo                  22781
#           Ohio           Columbus               47781
#           South Dakota   Sioux Falls            22973
#           Wisconsin      Milwaukee              23950
# Northeast Connecticut    Hartford               34696
#           Delaware       Wilmington             30275
#           Maine          Portland               22410
# ...

# %% [markdown]
# #### Using `pivot_table`

# %%
# Create a pivot table to show the number of products sold for region, state, and city
pt_products_sold = grouped_data.pivot_table(index=['region', 'state', 'city'], values='units_sold', aggfunc='sum')

# Rename the "units_sold" column to "Total_Products_Sold"
pt_products_sold.rename(columns={'units_sold': 'Total_Products_Sold'}, inplace=True)

# Show the top 5 result
top_5_results = pt_products_sold.nlargest(5, 'Total_Products_Sold')
top_5_results
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Create a pivot table to show the number of products sold for region, state, and city
# ----> 2 pt_products_sold = grouped_data.pivot_table(index=['region', 'state', 'city'], values='units_sold', aggfunc='sum')
#       4 # Rename the "units_sold" column to "Total_Products_Sold"
#       5 pt_products_sold.rename(columns={'units_sold': 'Total_Products_Sold'}, inplace=True)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:9193, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9176 @Substitution("")
#    9177 @Appender(_shared_docs["pivot_table"])
#    9178 def pivot_table(
#    (...)
#    9189     sort: bool = True,
#    9190 ) -> DataFrame:
# ...

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_sales = df1_df2.groupby(['region', 'state', 'city'])['total_sales'].sum().reset_index()

# Show the top 5 results.
top_5_results = grouped_sales.nlargest(5, 'total_sales')
top_5_results
# Out:
#        region           state           city  total_sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
#Create a pivot table to show total sales for each region, state, and city
pivot_table_sales = df1_df2.pivot_table(index=["region", "state", "city"], values="total_sales", aggfunc="sum")

# Rename the "total_sales" column to "Total Sales"
pivot_table_sales.rename(columns={"total_sales": "Total Sales"}, inplace=True)

# Sort the results in descending order to show the top 5 regions, states, and cities with the greatest number of products sold
top_5_results = pivot_table_sales.sort_values(by="Total Sales", ascending=False).head(5)

# Display the top 5 results
top_5_results
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_sales = df1_df2.groupby(['retailer', 'region', 'state', 'city'])['total_sales'].sum().reset_index()

grouped_sales.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# Show the top 5 results.
top_5_sales = grouped_sales.nlargest(5, 'Total Sales')
top_5_sales
# Out:
#         retailer     region           state           city  Total Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
pivot_table_sales = pd.pivot_table(df1_df2, 
                                   values='total_sales', 
                                   index=['retailer', 'region', 'state', 'city'], 
                                   aggfunc='sum').reset_index()

# Optional: Rename the "total_sales" column to "Total Sales"
pivot_table_sales.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# Show the top 5 results.
top_5_sales = pivot_table_sales.nlargest(5, 'Total Sales')

top_5_sales
# Out:
#         retailer     region           state           city  Total Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
womens_athletic_footwear_sales = df1_df2[df1_df2['product'] == "Women's Athletic Footwear"]
womens_athletic_footwear_sales
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 21    Foot Locker      1185732       1/4/20  Northeast      New York
# 22    Foot Locker      1185732       1/4/20  Northeast      New York
# 23    Foot Locker      1185732       1/4/20  Northeast      New York
# 26      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# 27      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9633  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 9634  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 9635       Amazon      1185732     12/30/21  Northeast         Maine
# 9636       Amazon      1185732     12/30/21  Northeast         Maine
# 9637  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
#
#               city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.


# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the table.

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.


# Sort the resampled pivot table in ascending order on "Total Sales".

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.


# Sort the resampled pivot table in ascending order on "Total Sales".
